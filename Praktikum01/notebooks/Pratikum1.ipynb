# %% [markdown]
# # **Menghubungkan dengan Google Drive dan Membaca File XML**

# %%
#menghubungkan colab dengan google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# membaca file csv menggunakan pandas
import pandas as pd

df = pd.read_xml("/content/gdrive/MyDrive/InformationRetrieval/Praktikum01/data/kompas-beritaPart1.xml")
df.head()
# Out:
#        sumber     tanggal   kategori  \
# 0  kompas.com  2015/07/01  Teknologi
# 1  kompas.com  2015/07/01  Teknologi
# 2  kompas.com  2015/07/01  Teknologi
# 3  kompas.com  2015/07/01  Teknologi
# 4  kompas.com  2015/07/01  Teknologi
#
#                                                judul  \
# 0      Ponsel Huawei Honor 4C Dibanderol Rp 2,2 Juta
# 1  Asosiasi: RPP E-commerce Tidak Sesuai Hasil Di...
# 2  Pemesan "iPhone Jadi Sabun" Karyawan Pesaing L...
# 3  "Autofeather Failure", Momok bagi Pesawat Bali...
# 4     Laptop Bezel Tertipis di Dunia Masuk Indonesia
#
#                                                  isi  \
# 0  JAKARTA, KOMPAS.com  Ponsel Android Huawei Hon...
# 1  JAKARTA, KOMPAS.com - Sejak 2013, wacana tenta...
# 2  JAKARTA, KOMPAS.com Danis Darusman, pelanggan ...
# 3  KOMPAS.com Salah satu momok yang dihadapi dala...
# 4  JAKARTA, KOMPAS.com - Resmi diperkenalkan pada...
#
#                                                 link  jumlahkata
# 0  http://tekno.kompas.com/read/xml/2015/07/01/18...         315
# 1  http://tekno.kompas.com/read/xml/2015/07/01/16...         419
# 2  http://tekno.kompas.com/read/xml/2015/07/01/15...         265
# 3  http://tekno.kompas.com/read/xml/2015/07/01/14...         481
# 4  http://tekno.kompas.com/read/xml/2015/07/01/14...         227

# %% [markdown]
# # **Eksplorasi Data**

# %%
# Mencari Informasi Data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1502 entries, 0 to 1501
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sumber      1502 non-null   object
#  1   tanggal     1502 non-null   object
#  2   kategori    1502 non-null   object
#  3   judul       1502 non-null   object
#  4   isi         1502 non-null   object
#  5   link        1502 non-null   object
#  6   jumlahkata  1502 non-null   int64
# dtypes: int64(1), object(6)
# memory usage: 82.3+ KB

# %%
# Memeriksa nilai NaN dan Duplikat

df.isnull().sum()
# Out:
# sumber        0
# tanggal       0
# kategori      0
# judul         0
# isi           0
# link          0
# jumlahkata    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # **Data Preparation / Data cleaning**

# %%
# Case Folding (mengubah huruf kapital menjadi huruf kecil)

def caseFolding(text):
  text = text.lower()
  return text

contoh = "Terima kasih Kak! Kamu sangat baik sekali kepadaku hari ini."
print(f'original: {contoh}')
print(f'case folded: {caseFolding(contoh)}')
# Out:
# original: Terima kasih Kak! Kamu sangat baik sekali kepadaku hari ini.
# case folded: terima kasih kak! kamu sangat baik sekali kepadaku hari ini.

# %%
# Punctuation Removal

import re
def punctuationRemoval(text):
  text = re.sub(r'[^\w\s]', '', text)
  return text

contoh = "Terima kasih, Kak! Kamu sangat baik sekali kepadaku hari ini."
print(f'original: {contoh}')
print(f'punctuation removed: {punctuationRemoval(contoh)}')
# Out:
# original: Terima kasih, Kak! Kamu sangat baik sekali kepadaku hari ini.
# punctuation removed: Terima kasih Kak Kamu sangat baik sekali kepadaku hari ini

# %%
# Menerapkan Function

df['clean'] = df['isi'].apply(caseFolding)
df['clean'] = df['clean'].apply(punctuationRemoval)
df.head()
# Out:
#        sumber     tanggal   kategori  \
# 0  kompas.com  2015/07/01  Teknologi
# 1  kompas.com  2015/07/01  Teknologi
# 2  kompas.com  2015/07/01  Teknologi
# 3  kompas.com  2015/07/01  Teknologi
# 4  kompas.com  2015/07/01  Teknologi
#
#                                                judul  \
# 0      Ponsel Huawei Honor 4C Dibanderol Rp 2,2 Juta
# 1  Asosiasi: RPP E-commerce Tidak Sesuai Hasil Di...
# 2  Pemesan "iPhone Jadi Sabun" Karyawan Pesaing L...
# 3  "Autofeather Failure", Momok bagi Pesawat Bali...
# 4     Laptop Bezel Tertipis di Dunia Masuk Indonesia
#
#                                                  isi  \
# 0  JAKARTA, KOMPAS.com  Ponsel Android Huawei Hon...
# 1  JAKARTA, KOMPAS.com - Sejak 2013, wacana tenta...
# 2  JAKARTA, KOMPAS.com Danis Darusman, pelanggan ...
# 3  KOMPAS.com Salah satu momok yang dihadapi dala...
# 4  JAKARTA, KOMPAS.com - Resmi diperkenalkan pada...
#
#                                                 link  jumlahkata  \
# 0  http://tekno.kompas.com/read/xml/2015/07/01/18...         315
# 1  http://tekno.kompas.com/read/xml/2015/07/01/16...         419
# 2  http://tekno.kompas.com/read/xml/2015/07/01/15...         265
# 3  http://tekno.kompas.com/read/xml/2015/07/01/14...         481
# 4  http://tekno.kompas.com/read/xml/2015/07/01/14...         227
#
#                                                clean
# 0  jakarta kompascom  ponsel android huawei honor...
# 1  jakarta kompascom  sejak 2013 wacana tentang r...
# 2  jakarta kompascom danis darusman pelanggan laz...
# 3  kompascom salah satu momok yang dihadapi dalam...
# 4  jakarta kompascom  resmi diperkenalkan pada aj...

# %% [markdown]
# # **Tokenisasi**

# %%
# Membuat Function Tokenisasi

def tokenize(text):
  return text.split(" ")

contoh = "Terima kasih Kak! Kamu sangat baik sekali kepadaku hari ini."
print(f'original: {contoh}')

clean = caseFolding(contoh)
clean = punctuationRemoval(clean)
print(f'tokenized: {tokenize(clean)}')
# Out:
# original: Terima kasih Kak! Kamu sangat baik sekali kepadaku hari ini.
# tokenized: ['terima', 'kasih', 'kak', 'kamu', 'sangat', 'baik', 'sekali', 'kepadaku', 'hari', 'ini']

# %%
# Menerapkan Tokenisasi

df['tokens'] = df['clean'].apply(tokenize)
df.head()
# Out:
#        sumber     tanggal   kategori  \
# 0  kompas.com  2015/07/01  Teknologi
# 1  kompas.com  2015/07/01  Teknologi
# 2  kompas.com  2015/07/01  Teknologi
# 3  kompas.com  2015/07/01  Teknologi
# 4  kompas.com  2015/07/01  Teknologi
#
#                                                judul  \
# 0      Ponsel Huawei Honor 4C Dibanderol Rp 2,2 Juta
# 1  Asosiasi: RPP E-commerce Tidak Sesuai Hasil Di...
# 2  Pemesan "iPhone Jadi Sabun" Karyawan Pesaing L...
# 3  "Autofeather Failure", Momok bagi Pesawat Bali...
# 4     Laptop Bezel Tertipis di Dunia Masuk Indonesia
#
#                                                  isi  \
# 0  JAKARTA, KOMPAS.com  Ponsel Android Huawei Hon...
# 1  JAKARTA, KOMPAS.com - Sejak 2013, wacana tenta...
# 2  JAKARTA, KOMPAS.com Danis Darusman, pelanggan ...
# 3  KOMPAS.com Salah satu momok yang dihadapi dala...
# 4  JAKARTA, KOMPAS.com - Resmi diperkenalkan pada...
#
#                                                 link  jumlahkata  \
# 0  http://tekno.kompas.com/read/xml/2015/07/01/18...         315
# 1  http://tekno.kompas.com/read/xml/2015/07/01/16...         419
# 2  http://tekno.kompas.com/read/xml/2015/07/01/15...         265
# 3  http://tekno.kompas.com/read/xml/2015/07/01/14...         481
# 4  http://tekno.kompas.com/read/xml/2015/07/01/14...         227
#
#                                                clean  \
# 0  jakarta kompascom  ponsel android huawei honor...
# 1  jakarta kompascom  sejak 2013 wacana tentang r...
# 2  jakarta kompascom danis darusman pelanggan laz...
# 3  kompascom salah satu momok yang dihadapi dalam...
# 4  jakarta kompascom  resmi diperkenalkan pada aj...
#
#                                               tokens
# 0  [jakarta, kompascom, , ponsel, android, huawei...
# 1  [jakarta, kompascom, , sejak, 2013, wacana, te...
# 2  [jakarta, kompascom, danis, darusman, pelangga...
# 3  [kompascom, salah, satu, momok, yang, dihadapi...
# 4  [jakarta, kompascom, , resmi, diperkenalkan, p...

# %% [markdown]
# # **Visualisasi**

# %%
# Frekuensi Kata

from collections import Counter

all_token = []
for tokens in df['tokens']:
  for token in tokens:
    all_token.append(token)

term_freq = Counter(all_token)
term_freq_df = pd.DataFrame(term_freq.items(), columns=['term', 'freq'])
term_freq_df_sorted = term_freq_df.sort_values(by='freq', ascending=False)
term_freq_df_sorted.head()
# Out:
#      term  freq
# 133  yang  6450
# 10     di  5824
# 126   dan  4915
# 2          4264
# 35    ini  2744

# %%
# Rank

term_freq_df_sorted['rank'] = term_freq_df_sorted['freq'].rank(method='first', ascending=False).astype(int)
term_freq_df_sorted.head()
# Out:
#      term  freq  rank
# 133  yang  6450     1
# 10     di  5824     2
# 126   dan  4915     3
# 2          4264     4
# 35    ini  2744     5

# %%
# Mengurutkan Berdasarkan Rank
term_freq_df_sorted['Rank'] = term_freq_df_sorted['Frequency (ft,d)'].rank(method='first', ascending=False).astype(int)

term_freq_df_sorted = term_freq_df_sorted.sort_values(by='Rank', ascending=True)
term_freq_df_sorted.head(20)
# Out:
#          term  Frequency (ft,d)  Rank
# 133      yang              6450     1
# 10         di              5824     2
# 126       dan              4915     3
# 2                          4264     4
# 35        ini              2744     5
# 23     dengan              2625     6
# 29      untuk              2583     7
# 31       dari              2460     8
# 18        itu              2437     9
# 97       akan              2055    10
# 107     dalam              1743    11
# 101      pada              1625    12
# 582   pesawat              1600    13
# 49      tidak              1513    14
# 146        ke              1428    15
# 59   tersebut              1300    16
# 104      juga              1245    17
# 756       tni              1174    18
# 258       ada              1127    19
# 268      kata              1105    20

# %%
# Zipf Law

term_freq_df_sorted['k = f * r'] = term_freq_df_sorted['Frequency (ft,d)'] * term_freq_df_sorted['Rank']
term_freq_df_sorted.head(n=100)
# Out:
#                 term  Frequency (ft,d)  Rank  k = f * r
# 133             yang              6450     1       6450
# 10                di              5824     2      11648
# 126              dan              4915     3      14745
# 2                                 4264     4      17056
# 35               ini              2744     5      13720
# ...              ...               ...   ...        ...
# 319             para               360    96      34560
# 1112           dapat               360    97      34920
# 10922  republikacoid               352    98      34496
# 406             lain               350    99      34650
# 441             jika               345   100      34500
#
# [100 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

rank = term_freq_df_sorted['Rank']
freq = term_freq_df_sorted['Frequency (ft,d)']
plt.figure(figsize=(10, 5))
plt.scatter(rank, freq, color='red', s=10)
plt.title("Term Frequency vs Rank")
plt.xlabel("Rank")
plt.ylabel("Frekuensi (f)")

plt.grid(True)
plt.show()

# %%
term_freq_df_sorted.columns
# Out:
# Index(['term', 'Frequency (ft,d)', 'Rank', 'k = f * r'], dtype='object')

# %%
# 10 kata dengan frekuensi terendah
term_freq_df_sorted_bottom = term_freq_df_sorted.sort_values(by='Frequency (ft,d)', ascending=True)
term_freq_df_sorted_bottom.head(10)
# Out:
#                 term  Frequency (ft,d)   Rank  k = f * r
# 18884    wargabegitu                 1  13348      13348
# 19175    kerabatkami                 1  13328      13328
# 19177           asih                 1  13327      13327
# 19178  katanyasesuai                 1  13326      13326
# 18177         bodong                 1  13357      13357
# 18176         wealth                 1  13356      13356
# 18175       barclays                 1  13355      13355
# 18174     prudential                 1  13354      13354
# 18173      reksadana                 1  13353      13353
# 18878        anggirs                 1  13352      13352

# %%
import matplotlib.pyplot as plt

# Ambil kolom frekuensi dan rank
freq = term_freq_df_sorted['Frequency (ft,d)']
rank = term_freq_df_sorted['Rank']

# Buat grafik distribusi frekuensi
plt.figure(figsize=(8, 6))
plt.plot(rank, freq, marker='', color='blue')
plt.title("Distribusi Frekuensi Kata pada Korpus Kompas (Part 1)")
plt.xlabel("Rank (Urutan Kata)")
plt.ylabel("Frekuensi (ft,d)")
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.show()
